# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
#Model
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
#Metric
from sklearn.metrics import accuracy_score, confusion_matrix


import joblib

# %%
df = pd.read_csv('downsampled_data.csv')
df
# Out:
#      pressure  dewpoint  humidity  cloud  rainfall  sunshine  winddirection  \
# 0      1008.2      25.0        85     81         1       2.5             90
# 1      1013.4      19.5        69     17         0      10.5             70
# 2      1006.1      24.4        74     27         0      10.8            220
# 3      1016.8      16.8        95     95         1       0.0             60
# 4      1021.2       8.4        66     18         0      10.1             20
# ..        ...       ...       ...    ...       ...       ...            ...
# 229    1009.9      22.5        84     85         1       3.5             70
# 230    1027.1       3.4        70     95         1       0.0             20
# 231    1027.1       2.5        59     85         1       0.4             20
# 232    1008.3      24.1        74     29         0       5.7             10
# 233    1009.1      26.0        82     86         1       2.7            200
#
#      windspeed
# 0         15.1
# 1         12.4
# 2          8.7
# 3         35.1
# 4         24.4
# ..         ...
# 229       26.4
# 230       55.5
# 231       21.3
# 232        4.4
# 233       21.9
#
# [234 rows x 8 columns]

# %%
df['rainfall'].value_counts()
# Out:
# rainfall
# 1    117
# 0    117
# Name: count, dtype: int64

# %%
x = df.drop('rainfall' ,axis = 1)
y = df['rainfall']
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.1, random_state= 42)

# %%
model = SVC(kernel = 'linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.5

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_log = log_reg.predict(X_test)
accuracy_score(y_test,y_pred_log)
# Out:
# 0.5

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dt = dt.predict(X_test)
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.625

# %%
joblib.dump(dt,'model.pkl')
# Out:
# ['model.pkl']
